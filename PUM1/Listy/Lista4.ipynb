// %% [markdown]
// # Lista 4

// %% [markdown]
// ### Termin wykonania:
// 07.05.2026

// %% [markdown]
// Zadania wykonaj wykorzystując metody transformacji, filtrowania, testowania (`map`, `all`, `groupBy`, etc.), oraz łańcuchowania metod.
//
// ``` kotlin
// val numbers = listOf(5, 12, 3, 19, 8)
//
// val result = number
//     .filter {it > 5}
//     .map {it * 2}
//     .sorted()
//     .joinToString(" - ")
//
// println(result)
// ```
//
// ```
// >>> 16 - 24 - 38
// ```
//
// Przygotujmy dane dla aplikacji zarządzającej kosztami posiadanych samochodów. Dla uproszczenia zakładamy koszty tylko z roku 2025.
//
// Typ kosztu zdefiniujemy jako `enum class`.

// %%
enum class CostType(val costType: String) {
    REFUELING("Tankowanie"),
    SERVICE("Serwis"),
    PARKING("Parking"),
    INSURANCE("Ubezpieczenie"),
    TICKET("Mandat")
}

// %% [markdown]
// Model danych zawiera typ kosztu, datę oraz kwotę.

// %%
data class Cost (
    val type: CostType,
    val date: LocalDate,
    val amount: Int
)

// %% [markdown]
// W objekcie `DataProvider` znajduje się wygenerowana lista kosztów.

// %%
import kotlin.random.*

object DataProvider {
    val generalCosts = List(5) {
        Cost(
            CostType
                .values()[Random.nextInt(CostType.values().size)],
            LocalDate.of(
                2025, 
                Random.nextInt(1,13), 
                Random.nextInt(1,28)),
            Random.nextInt(5000)
        )
    }
}

// %% [markdown]
// ## Zad 1 - **1 pkt**
//
// Napisz funkcję `groupedCostMap` przyjmującą listę kosztów `List<Cost>`, która zwróci mapę kosztów pogrupowaną według miesiąców i posortowaną rosnąco .
//
// ```verbatim
// input:
// >> groupedCostMap(DataProvider.generalCosts)
//
// generując 5 elementów
// output:
// >> {JANUARY=[Cost(type=INSURANCE, date=2025-01-15, amount=2263)], APRIL=[Cost(type=SERVICE, date=2025-04-20, amount=1933)], AUGUST=[Cost(type=INSURANCE, date=2025-08-24, amount=1524), Cost(type=PARKING, date=2025-08-13, amount=2350)], DECEMBER=[Cost(type=PARKING, date=2025-12-15, amount=529)]}
// ```

// %% [markdown]
// ## Zad 2 - **2 pkt**
//
// Napisz funkcję drukującą wszystkie koszty.
// - koszty powinny być pogrupowane według miesięcy
// - koszty powinny być posortowane według dat
//
// ```verbatim
// format:
// <miesiąc>
// <dzień> <koszt> <kwota>
// <dzień> <koszt> <kwota>
// ...
// <miesiąc>
// <dzień> <koszt> <kwota>
// <dzień> <koszt> <kwota>
//
//
// output:
// JANUARY
// 01 INSURANCE 2012 zł
// 15 PARKING 300 zł
// APRIL
// 04 SERVICE 1933 zł
// DECEMBER
// 24 TICKET 2500 zł
// ```

// %% [markdown]
// ## Zad 3 - **1 pkt**
//
// Zdefiniuj typ wyniku raportu miesięcznego jako sealed class:
// - `NoCosts` – gdy w danym miesiącu nie ma żadnych kosztów,
// - `WithinLimit(total: Int)` – gdy suma kosztów w miesiącu jest mniejsza lub równa limitowi,
// - `OverLimit(total: Int, exceededBy: Int)` – gdy suma kosztów przekracza limit.
//
// Następnie zaimplementuj funkcję:
//
// ```kotlin
// fun classifyMonthlyCosts(costs: List<Cost>, month: Month, limit: Int): MonthlyCostStatus
// ```
//
// Wymagania:
// - filtruj koszty tylko dla podanego miesiąca,
// - policz sumę (sumOf),
// - zwróć odpowiedni wariant sealed class,
// - bez klasycznych pętli.
//
// Przykład wykonania:
// ```kotlin
// val costs = listOf(
//     Cost(CostType.REFUELING, LocalDate.of(2025, 1, 10), 300),
//     Cost(CostType.PARKING, LocalDate.of(2025, 1, 12), 50),
//     Cost(CostType.SERVICE, LocalDate.of(2025, 2, 4), 1200)
// )
//
// println(classifyMonthlyCosts(costs, Month.JANUARY, 400))
// println(classifyMonthlyCosts(costs, Month.FEBRUARY, 1000))
// println(classifyMonthlyCosts(costs, Month.MARCH, 500))
// ```
//
// ```verbatim
// >> WithinLimit(total=350)
// >> OverLimit(total=1200, exceededBy=200)
// >> NoCosts
// ```

// %% [markdown]
// ## Zad 4 - **1 pkt**
//
// Zdefiniuj interfejs:
// ```kotlin
// interface CostFormatter {
//     fun format(cost: Cost): String
// }
// ```
//
// oraz singleton `object` implementujący ten interfejs (np. `PlCostFormatter`), który formatuje koszt w postaci:
// ```verbatim
// DD TYPE KWOTA zł
// ```
//
// Następnie napisz funkcję:
// ```kotlin
// fun formatCosts(costs: List<Cost>, formatter: CostFormatter): String
// ```
//
// Wymagania:
// - koszty mają być posortowane po dacie rosnąco,
// - każda linia ma być sformatowana przez formatter,
// - wynik zwracany jako jeden String (np. joinToString("\n")),
// - użyj łańcuchowania metod (bez klasycznej pętli).
//
// ```kotlin
// val costs = listOf(
//     Cost(CostType.PARKING, LocalDate.of(2025, 1, 15), 30),
//     Cost(CostType.SERVICE, LocalDate.of(2025, 1, 5), 900)
// )
//
// println(formatCosts(costs, PlCostFormatter))
// ```
//
// ```verbatim
// >> 05 SERVICE 900 zł
// >> 15 PARKING 30 zł
// ```

// %% [markdown]
// Pytania:
// 1. Jaka jest różnica między kolekcją read-only (List, Set, Map) a kolekcją mutowalną (MutableList, MutableSet, MutableMap) w Kotlinie? (1 pkt)
// 2. Dlaczego Kotlin rozdziela interfejsy kolekcji na read-only i mutable na poziomie systemu typów? (1 pkt)
// 3. Jakie są najważniejsze cechy List? (1 pkt)
// 4. Jakie są najważniejsze cechy Set? (1 pkt)
// 5. Dlaczego dwa zbiory (Set) mogą być równe mimo innej kolejności elementów? (1 pkt)
// 6. Jakie są najważniejsze cechy Map i czym różni się klucz od wartości? (1 pkt)
// 7. Co się stanie, gdy do mapy dodamy wartość pod istniejącym już kluczem? (1 pkt)
// 8. Jak iterować po mapie z użyciem destrukturyzacji (for ((k, v) in map)) i dlaczego to wygodne? (1 pkt)
// 9. Do czego służy funkcja map w przetwarzaniu kolekcji? (1 pkt)
// 10. Czym różnią się map, mapKeys i mapValues? (1 pkt)
// 11. Do czego służą zip i unzip? Co się dzieje, gdy kolekcje mają różne długości? (1 pkt)
// 12. Czym różni się associateBy od associateWith? (1 pkt)
// 13. Kiedy lepiej użyć associateBy, a kiedy groupBy? (1 pkt)
// 14. Do czego służy groupBy i jaki typ danych zwykle zwraca? (1 pkt)
// 15. Czym różnią się od siebie funkcje testujące all, any, none? (1 pkt)
// 16. Do czego służy filter i czym różni się od map? (1 pkt)
// 17. Czym różni się klasa od obiektu (instancji) w programowaniu obiektowym? (1 pkt)
// 18. Jaką rolę pełni blok init w klasie Kotlin? (1 pkt)
// 19. Kiedy używa się konstruktora drugorzędnego (secondary constructor)? (1 pkt)
// 20. Jakie są modyfikatory dostępu w Kotlinie? (1 pkt)
// 21. Czym data class różni się od zwykłej klasy? (1 pkt)
// 22. Do czego służy copy() i dlaczego jest ważne przy niemutowalności danych? (1 pkt)
// 23. Czym różni się == od === w Kotlinie? (1 pkt)
// 24. Które pola data class biorą udział w equals() i hashCode() — wszystkie czy tylko część? (1 pkt)
// 25. Po co używa się enum class i czym różni się od zwykłej klasy? (1 pkt)
// 26. Do czego służą słowa kluczowe open, override i final override? (1 pkt)
// 27. Czym różni się klasa abstrakcyjna od klasy open? (1 pkt)
// 28. Czym różni się abstract fun od open fun? (1 pkt)
// 29. Czym jest sealed class i jaki problem rozwiązuje? (1 pkt)
// 30. Dlaczego sealed class dobrze nadaje się do modelowania stanów (np. Loading / Success / Error)? (1 pkt)
// 31. Czym różni się klasa zagnieżdżona (nested) od klasy wewnętrznej (inner) w Kotlinie? (1 pkt)
// 32. Dlaczego inner class wymaga instancji klasy zewnętrznej i co daje this@Outer? (1 pkt)
// 33. Czym jest deklaracja object w Kotlinie i do czego służy? (1 pkt)
// 34. Co oznacza, że obiekt object jest inicjalizowany leniwie (lazy)? (1 pkt)
// 35. Czym różni się object declaration (nazwany singleton) od object expression (anonimowy obiekt)? (1 pkt)
// 36. Kiedy używa się object expression zamiast tworzenia osobnej klasy? (1 pkt)
// 37. Czy obiekt tworzony przez object może implementować interfejs albo dziedziczyć po klasie? (1 pkt)
// 38. Co to jest data object i kiedy jest przydatny? (1 pkt)
// 39. Czym jest interfejs w Kotlinie i co oznacza, że definiuje „kontrakt”? (1 pkt)
// 40. Czy klasa może implementować wiele interfejsów, ale dziedziczyć tylko po jednej klasie, czy na odwrót? (1 pkt)
// 41. Jak rozwiązać konflikt metod domyślnych, gdy dwa interfejsy implementowane przez tą samą klasę mają metodę o tej samej sygnaturze? (1 pkt)
// 42. Jaką rolę pełni interfejs jako typ? (1 pkt)
// 43. Co to jest interfejs markerowy (znacznikowy) i do czego może służyć? (1 pkt)
// 44. Czym jest interfejs funkcyjny (SAM) i jaki warunek musi spełniać? (1 pkt)
// 45. Po co w Kotlinie używa się fun interface? (1 pkt)
// 46. Na czym polega konwersja SAM i jaka jest jej praktyczna korzyść? (1 pkt)
// 47. Co to jest companion object i do czego służy w Kotlinie? (1 pkt)
// 48. Co to jest klasa generyczna i jaką korzyść daje parametr typu <T>? (1 pkt)

// %% [markdown]
// ### Oceny
//
// |**ocena**|**punkty**|
// |:---:|:---:|
// |3,0 | 6 pkt|
// |3,5 | 7 pkt|
// |4,0 | 8 pkt|
// |4,5 | 9 pkt|
// |5,0 | 10 pkt|
